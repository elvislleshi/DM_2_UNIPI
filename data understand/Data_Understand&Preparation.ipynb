# %%
import pandas as pd
 
df=pd.read_csv('imdb.csv')

# %%
df
# Out:
#                                   originalTitle  rating  startYear endYear  \
# 0                                    Carmencita  (5, 6]       1894      \N
# 1                                   Un bon bock  (5, 6]       1892      \N
# 2                             Chinese Opium Den  (4, 5]       1894      \N
# 3        Edison Kinetoscopic Record of a Sneeze  (5, 6]       1894      \N
# 4              L'arrivée d'un train à La Ciotat  (7, 8]       1896      \N
# ...                                         ...     ...        ...     ...
# 149526                         Nuestra película  (6, 7]       1993      \N
# 149527                                      Eco  (6, 7]       2019      \N
# 149528                  Women Take Center Stage  (5, 6]       2019      \N
# 149529  Horrid Henry and the Christening Crisis  (7, 8]       2011      \N
# 149530             A lenda do soprador de vidro  (8, 9]       2019      \N
#
#        runtimeMinutes  awardWins  numVotes  worstRating  bestRating  \
# 0                   1          0      2089            1          10
# 1                  12          0       183            1          10
# 2                   1          0       195            1          10
# 3                   1          1      2237            1          10
# 4                   1          0     13115            1          10
# ...               ...        ...       ...          ...         ...
# 149526             96          0        11            1          10
# 149527             14          0        15            1          10
# 149528             \N          0        12            1          10
# 149529             10          0         9            1          10
# 149530             \N          0         9            1          10
#
#         totalImages  ...                      genres  castNumber  \
# 0                 2  ...           Documentary,Short           1
# 1                 2  ...             Animation,Short           0
# 2                 1  ...                       Short           0
# 3                 3  ...           Documentary,Short           1
# 4                12  ...           Documentary,Short           6
# ...             ...  ...                         ...         ...
# 149526            0  ...                 Documentary           0
# 149527            4  ...                 Drama,Short           6
# 149528            2  ...                  Reality-TV           1
# 149529            1  ...  Adventure,Animation,Comedy           7
# 149530            3  ...                      Comedy           9
#
#         companiesNumber averageRating  \
# 0                     3           5.7
# 1                     0           5.4
# 2                     1           5.0
# 3                     6           5.4
# 4                     5           7.4
# ...                 ...           ...
# 149526                2           7.0
# 149527                3           6.4
# 149528                0           5.6
# 149529                0           7.1
# 149530                0           8.6
#
#                                                   regions  externalLinks  \
# 0       ['\\N', 'DE', 'US', 'HU', 'GR', 'RU', 'UA', 'JP']              9
# 1             ['\\N', 'HU', 'DE', 'FR', 'RO', 'RU', 'JP']              3
# 2                   ['\\N', 'US', 'DE', 'PT', 'HU', 'RU']              4
# 3             ['\\N', 'UA', 'JP', 'HU', 'US', 'DE', 'RU']              6
# 4       ['\\N', 'HU', 'DE', 'TR', 'FI', 'FR', 'IT', 'E...             21
# ...                                                   ...            ...
# 149526                                      ['\\N', 'CO']              1
# 149527                                      ['\\N', 'ES']              5
# 149528                                            ['\\N']              0
# 149529                                            ['\\N']              0
# 149530                                            ['\\N']              0
#
#         writerCredits  directorsCredits  soundMixes  quotesTotal
# 0                   0                 1  ['silent']            0
# 1                   0                 1  ['silent']            0
# 2                   0                 1  ['silent']            0
# 3                   0                 1  ['silent']            0
# 4                   0                 2  ['silent']            0
# ...               ...               ...         ...          ...
# 149526              1                 1          []            0
# 149527              1                 1          []            0
# 149528              0                 0          []            0
# 149529              3                 1          []            0
# 149530              3                 2          []            0
#
# [149531 rows x 32 columns]

# %%
import pandas as pd

# Kontrollo për NaN në të gjithë dataset-in
nan_values = df.isna().sum()

# Shfaq rezultatet për NaN
print(nan_values)
# Out:
# originalTitle                      0
# rating                             0
# startYear                          0
# endYear                            0
# runtimeMinutes                     0
# awardWins                          0
# numVotes                           0
# worstRating                        0
# bestRating                         0
# totalImages                        0
# totalVideos                        0
# totalCredits                       0
# criticReviewsTotal                 0
# titleType                          0
# awardNominationsExcludeWins        0
# canHaveEpisodes                    0
# isRatable                          0
# isAdult                            0
# numRegions                         0
# userReviewsTotal                   0
# ratingCount                        0
# countryOfOrigin                39987
# genres                             0
# castNumber                         0
# companiesNumber                    0
# averageRating                      0
# regions                            0
# externalLinks                      0
# writerCredits                      0
# directorsCredits                   0
# soundMixes                         0
# quotesTotal                        0
# dtype: int64

# %%
# Gjeni tipin e të dhënave për çdo kolonë
print(df.dtypes)
# Out:
# originalTitle                   object
# rating                          object
# startYear                        int64
# endYear                         object
# runtimeMinutes                  object
# awardWins                        int64
# numVotes                         int64
# worstRating                      int64
# bestRating                       int64
# totalImages                      int64
# totalVideos                      int64
# totalCredits                     int64
# criticReviewsTotal               int64
# titleType                       object
# awardNominationsExcludeWins      int64
# canHaveEpisodes                   bool
# isRatable                         bool
# isAdult                          int64
# numRegions                       int64
# userReviewsTotal                 int64
# ratingCount                      int64
# countryOfOrigin                 object
# genres                          object
# castNumber                       int64
# companiesNumber                  int64
# averageRating                  float64
# regions                         object
# externalLinks                    int64
# writerCredits                    int64
# directorsCredits                 int64
# soundMixes                      object
# quotesTotal                      int64
# dtype: object

# %%
# Shiko vlerat unike në kolonën 'genres'
unique_genres = df['genres'].unique()

# Shfaq vlerat unike
print(unique_genres)
# Out:
# ['Documentary,Short' 'Animation,Short' 'Short' ...
#  'Drama,Mystery,Reality-TV' 'Adventure,Animation,Romance'
#  'Adult,Reality-TV,Romance']

# %%
# Shpërndaj genre-t e ndara me presje në elemente të veçanta
genres_exploded = df['genres'].str.split(',').explode()

# Shiko vlerat unike të genres
unique_genres = genres_exploded.unique()

# Shfaq vlerat unike
print(unique_genres)
# Out:
# ['Documentary' 'Short' 'Animation' 'Comedy' 'Sport' 'Drama' 'Fantasy'
#  'Horror' 'War' 'Action' 'Crime' 'History' 'News' 'Music' 'Adventure'
#  'Western' 'Family' 'Mystery' 'Romance' 'Biography' '\\N' 'Thriller'
#  'Sci-Fi' 'Musical' 'Film-Noir' 'Reality-TV' 'Game-Show' 'Talk-Show'
#  'Adult']

# %%
# Kontrollo për rreshta të plotë të dublikuar
duplicates = df.duplicated()

# Shfaq rreshtat e dublikuar
print(df[duplicates])
# Out:
#                                             originalTitle  rating  startYear  \
# 61836         Paradise Found: Creating the Director's Cut  (7, 8]       2006
# 81847                Bryan Cranston/Julia Garner/Surfaces  (7, 8]       2020
# 83077                             Masters of the Universe  (7, 8]       2020
# 101058              The Making of Humanoids from the Deep  (7, 8]       2010
# 138209                      Adam Levine/Josh Gad/Maroon 5  (6, 7]       2017
# 138320         Morgan Freeman/Norman Reedus/Joe Zimmerman  (6, 7]       2017
# 140635  Kenan Thompson/Leah Remini/Bryan Fogel/Roy May...  (6, 7]       2017
# 141603         Jeff Bridges/David Boreanaz/Liam Gallagher  (6, 7]       2017
# 142611          Nick Jonas/Dennis Rodman/Jeezy/Tory Lanez  (6, 7]       2017
# 143497                        Maze Runner: The Death Cure  (7, 8]       2018
#
#        endYear runtimeMinutes  awardWins  numVotes  worstRating  bestRating  \
# 61836       \N              9          0        20            1          10
# 81847       \N             41          0         8            1          10
# 83077       \N             92          0        18            1          10
# 101058      \N             23          0        13            1          10
# 138209      \N             41          0        15            1          10
# 138320      \N             41          0        22            1          10
# 140635      \N             57          0        20            1          10
# 141603      \N             40          0        16            1          10
# 142611      \N             41          0        26            1          10
# 143497      \N             \N          0         8            1          10
#
#         totalImages  ...                  genres  castNumber  companiesNumber  \
# 61836             0  ...                   Short           6                2
# 81847             0  ...  Comedy,Music,Talk-Show           6                0
# 83077             2  ...                  Comedy           2                0
# 101058            0  ...       Documentary,Short           9                2
# 138209            0  ...  Comedy,Music,Talk-Show           9                3
# 138320            0  ...  Comedy,Music,Talk-Show          11                3
# 140635            0  ...        Comedy,Talk-Show           7               12
# 141603            3  ...        Comedy,Talk-Show           5                0
# 142611            1  ...        Comedy,Talk-Show           7                4
# 143497            1  ...                  Comedy           1                0
#
#        averageRating        regions  externalLinks  writerCredits  \
# 61836            7.4  ['\\N', 'US']              0              0
# 81847            8.0  ['\\N', 'US']             39             14
# 83077            7.5  ['\\N', 'DE']              0              2
# 101058           7.2  ['\\N', 'US']              0              0
# 138209           7.0  ['\\N', 'US']             39              2
# 138320           6.7  ['\\N', 'US']             39             24
# 140635           6.4  ['\\N', 'US']              0              1
# 141603           6.4  ['\\N', 'US']             38              8
# 142611           6.2  ['\\N', 'US']             22              1
# 143497           7.8        ['\\N']              0              0
#
#         directorsCredits         soundMixes  quotesTotal
# 61836                  1  ['dolby_digital']            0
# 81847                  2         ['stereo']            0
# 83077                  0                 []            0
# 101058                 0  ['dolby_digital']            0
# 138209                 0         ['stereo']            0
# 138320                 1         ['stereo']            0
# 140635                 0                 []            0
# 141603                 1         ['stereo']            0
# 142611                 0         ['stereo']            0
# 143497                 0                 []            0
#
# [10 rows x 32 columns]

# %%
# Fshi rreshtat e dublikuar
df_no_duplicates = df.drop_duplicates()

# Shfaq DataFrame-n pa dublikate
print(df_no_duplicates)
# Out:
#                                   originalTitle  rating  startYear endYear  \
# 0                                    Carmencita  (5, 6]       1894      \N
# 1                                   Un bon bock  (5, 6]       1892      \N
# 2                             Chinese Opium Den  (4, 5]       1894      \N
# 3        Edison Kinetoscopic Record of a Sneeze  (5, 6]       1894      \N
# 4              L'arrivée d'un train à La Ciotat  (7, 8]       1896      \N
# ...                                         ...     ...        ...     ...
# 149526                         Nuestra película  (6, 7]       1993      \N
# 149527                                      Eco  (6, 7]       2019      \N
# 149528                  Women Take Center Stage  (5, 6]       2019      \N
# 149529  Horrid Henry and the Christening Crisis  (7, 8]       2011      \N
# 149530             A lenda do soprador de vidro  (8, 9]       2019      \N
#
#        runtimeMinutes  awardWins  numVotes  worstRating  bestRating  \
# 0                   1          0      2089            1          10
# 1                  12          0       183            1          10
# 2                   1          0       195            1          10
# 3                   1          1      2237            1          10
# 4                   1          0     13115            1          10
# ...               ...        ...       ...          ...         ...
# 149526             96          0        11            1          10
# 149527             14          0        15            1          10
# 149528             \N          0        12            1          10
# 149529             10          0         9            1          10
# 149530             \N          0         9            1          10
#
#         totalImages  ...                      genres  castNumber  \
# 0                 2  ...           Documentary,Short           1
# 1                 2  ...             Animation,Short           0
# 2                 1  ...                       Short           0
# 3                 3  ...           Documentary,Short           1
# 4                12  ...           Documentary,Short           6
# ...             ...  ...                         ...         ...
# 149526            0  ...                 Documentary           0
# 149527            4  ...                 Drama,Short           6
# 149528            2  ...                  Reality-TV           1
# 149529            1  ...  Adventure,Animation,Comedy           7
# 149530            3  ...                      Comedy           9
#
#         companiesNumber averageRating  \
# 0                     3           5.7
# 1                     0           5.4
# 2                     1           5.0
# 3                     6           5.4
# 4                     5           7.4
# ...                 ...           ...
# 149526                2           7.0
# 149527                3           6.4
# 149528                0           5.6
# 149529                0           7.1
# 149530                0           8.6
#
#                                                   regions  externalLinks  \
# 0       ['\\N', 'DE', 'US', 'HU', 'GR', 'RU', 'UA', 'JP']              9
# 1             ['\\N', 'HU', 'DE', 'FR', 'RO', 'RU', 'JP']              3
# 2                   ['\\N', 'US', 'DE', 'PT', 'HU', 'RU']              4
# 3             ['\\N', 'UA', 'JP', 'HU', 'US', 'DE', 'RU']              6
# 4       ['\\N', 'HU', 'DE', 'TR', 'FI', 'FR', 'IT', 'E...             21
# ...                                                   ...            ...
# 149526                                      ['\\N', 'CO']              1
# 149527                                      ['\\N', 'ES']              5
# 149528                                            ['\\N']              0
# 149529                                            ['\\N']              0
# 149530                                            ['\\N']              0
#
#         writerCredits  directorsCredits  soundMixes  quotesTotal
# 0                   0                 1  ['silent']            0
# 1                   0                 1  ['silent']            0
# 2                   0                 1  ['silent']            0
# 3                   0                 1  ['silent']            0
# 4                   0                 2  ['silent']            0
# ...               ...               ...         ...          ...
# 149526              1                 1          []            0
# 149527              1                 1          []            0
# 149528              0                 0          []            0
# 149529              3                 1          []            0
# 149530              3                 2          []            0
#
# [149521 rows x 32 columns]

# %%
# Shiko vlerat unike të kolones 'startYear'
unique_start_years = df['startYear'].unique()

# Shfaq vlerat unike
print(unique_start_years)
# Out:
# [1894 1892 1896 1895 1898 1897 1900 1899 1901 1902 1903 1905 1907 1906
#  1908 1909 1911 1910 1912 1913 1914 1915 1916 1917 1922 1918 1919 1921
#  1920 1923 1924 1925 1926 1927 1928 1929 1930 1931 1950 1938 1932 1934
#  1933 1946 1935 1936 1939 1937 1941 1940 1942 1943 1948 1944 1945 1953
#  1947 1949 1951 1952 1958 1956 1955 1954 1977 1957 1960 1959 1961 1962
#  1963 1964 1965 1966 1967 1969 1968 1972 1973 1971 1970 1974 1975 2010
#  2018 2023 1976 2022 1979 1978 1982 1980 1983 1987 1984 1981 1986 1992
#  1989 1985 1988 1991 1993 1990 1996 1995 1994 1999 1997 1998 2017 2005
#  2001 2002 1904 2003 2009 2004 2012 2006 2019 2011 2007 1891 2013 2015
#  2008 1890 2020 2016 2014 2021 2024 1878 1893 1881 1887]

# %%
# Shiko vlerat unike të kolones 'quotesTotal'
unique_quotes_total = df['quotesTotal'].unique()

# Shfaq vlerat unike
print(unique_quotes_total)
# Out:
# [   0    1    5    2    6    9   17    3   20    8    7   11   15   10
#    13    4   19   24   12   16   18   26   21   33   14   35   41   22
#    47   88   55   32   28   36   31   44   38   42   39   43   25   27
#    23   62   34   52   48   61   56   46   29   30   49   37   40   93
#    57   51   79   58   59   69   95   80   91   66   90   53   89   50
#    78   65   82   77  135   64   45   73   54   63   76   71   60   87
#    68   74   92  124  108  161   83   81   67  131   70  111  126   96
#   106   86  112   75  110  109  123   98  137  103  136  107  116  138
#   162  664   72   99 1084  105   85  258  145  128   94   97  122  214
#   358  156  943  654  270  114  133  192  147  100  203]

# %%
# Check data types of each column
print(df.dtypes)

# Get summary statistics for numerical columns
print(df.describe())

# Check for missing values in
# Out:
# originalTitle                   object
# rating                          object
# startYear                        int64
# endYear                         object
# runtimeMinutes                  object
# awardWins                        int64
# numVotes                         int64
# worstRating                      int64
# bestRating                       int64
# totalImages                      int64
# totalVideos                      int64
# totalCredits                     int64
# criticReviewsTotal               int64
# titleType                       object
# awardNominationsExcludeWins      int64
# canHaveEpisodes                   bool
# isRatable                         bool
# isAdult                          int64
# numRegions                       int64
# userReviewsTotal                 int64
# ratingCount                      int64
# countryOfOrigin                 object
# genres                          object
# castNumber                       int64
# companiesNumber                  int64
# averageRating                  float64
# regions                         object
# externalLinks                    int64
# writerCredits                    int64
# directorsCredits                 int64
# soundMixes                      object
# quotesTotal                      int64
# dtype: object
#            startYear      awardWins      numVotes  worstRating  bestRating  \
# count  149531.000000  149531.000000  1.495310e+05     149531.0    149531.0
# mean     1994.939852       0.308558  1.085135e+03          1.0        10.0
# std        24.890965       2.912763  1.999973e+04          0.0         0.0
# min      1878.000000       0.000000  5.000000e+00          1.0        10.0
# 25%      1981.000000       0.000000  1.200000e+01          1.0        10.0
# 50%      1999.000000       0.000000  2.800000e+01          1.0        10.0
# 75%      2015.000000       0.000000  1.070000e+02          1.0        10.0
# max      2024.000000     446.000000  2.947931e+06          1.0        10.0
#
#          totalImages    totalVideos   totalCredits  criticReviewsTotal  \
# count  149531.000000  149531.000000  149531.000000       149531.000000
# mean        9.531856       0.235851      57.619009            2.191653
# std       101.653836       5.084344     154.168251           13.944788
# min         0.000000       0.000000       0.000000            0.000000
# 25%         1.000000       0.000000      16.000000            0.000000
# 50%         1.000000       0.000000      34.000000            0.000000
# 75%         4.000000       0.000000      64.000000            0.000000
# max     20586.000000    1063.000000   25218.000000          628.000000
#
#        awardNominationsExcludeWins  ...     numRegions  userReviewsTotal  \
# count                149531.000000  ...  149531.000000     149531.000000
# mean                      0.418916  ...       2.846554          5.572791
# std                       4.384281  ...       5.295663         66.404683
# min                       0.000000  ...       0.000000          0.000000
# 25%                       0.000000  ...       1.000000          0.000000
# 50%                       0.000000  ...       1.000000          0.000000
# 75%                       0.000000  ...       3.000000          1.000000
# max                     650.000000  ...     100.000000      11289.000000
#
#         ratingCount     castNumber  companiesNumber  averageRating  \
# count  1.495310e+05  149531.000000    149531.000000  149531.000000
# mean   1.085733e+03      19.519832         5.821341       6.874827
# std    2.000802e+04      82.618284        19.657756       1.348353
# min    5.000000e+00       0.000000         0.000000       1.000000
# 25%    1.200000e+01       5.000000         1.000000       6.100000
# 50%    2.800000e+01      12.000000         2.000000       7.100000
# 75%    1.070000e+02      21.000000         5.000000       7.800000
# max    2.948790e+06   10649.000000       597.000000      10.000000
#
#        externalLinks  writerCredits  directorsCredits    quotesTotal
# count  149531.000000  149531.000000     149531.000000  149531.000000
# mean        5.177261       2.003725          0.945276       1.067772
# std        19.928593       2.467848          0.796154       7.025515
# min         0.000000       0.000000          0.000000       0.000000
# 25%         0.000000       0.000000          1.000000       0.000000
# 50%         1.000000       1.000000          1.000000       0.000000
# 75%         3.000000       3.000000          1.000000       0.000000
# max       744.000000      51.000000         58.000000    1084.000000
#
# [8 rows x 21 columns]

# %%
# Llogarit matricën e korrelacionit
correlation_matrix = df.corr()

# Shfaq matricën e korrelacionit
print(correlation_matrix)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 2
#       1 # Llogarit matricën e korrelacionit
# ----> 2 correlation_matrix = df.corr()
#       4 # Shfaq matricën e korrelacionit
#       5 print(correlation_matrix)
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1991 if dtype is not None:
#    1992     dtype = np.dtype(dtype)
# -> 1993 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994 if result.dtype is not dtype:
#    1995     result = np.asarray(result, dtype=dtype)
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/internals/managers.py:1694, in BlockManager.as_array(self, dtype, copy, na_value)
#    1692         arr.flags.writeable = False
#    1693 else:
# -> 1694     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1695     # The underlying data was copied within _interleave, so no need
#    1696     # to further copy if copy=True or setting na_value
#    1698 if na_value is lib.no_default:
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/internals/managers.py:1753, in BlockManager._interleave(self, dtype, na_value)
#    1751     else:
#    1752         arr = blk.get_values(dtype)
# -> 1753     result[rl.indexer] = arr
#    1754     itemmask[rl.indexer] = 1
#    1756 if not itemmask.all():
#
# ValueError: could not convert string to float: 'Carmencita'

# %%
# Zgjidh vetëm kolonat numerike
numeric_df = df.select_dtypes(include=['number'])

# Llogarit matricën e korrelacionit
correlation_matrix = numeric_df.corr()

# Shfaq matricën e korrelacionit
print(correlation_matrix)
# Out:
#                              startYear  awardWins  numVotes  worstRating  \
# startYear                     1.000000   0.036587  0.008576          NaN
# awardWins                     0.036587   1.000000  0.284973          NaN
# numVotes                      0.008576   0.284973  1.000000          NaN
# worstRating                        NaN        NaN       NaN          NaN
# bestRating                         NaN        NaN       NaN          NaN
# totalImages                  -0.003611   0.198175  0.178825          NaN
# totalVideos                   0.027005   0.107434  0.161267          NaN
# totalCredits                  0.069372   0.241754  0.196506          NaN
# criticReviewsTotal            0.003592   0.306619  0.592157          NaN
# awardNominationsExcludeWins   0.035496   0.726617  0.346974          NaN
# isAdult                      -0.005848  -0.008815 -0.007046          NaN
# numRegions                   -0.092510   0.227115  0.369382          NaN
# userReviewsTotal              0.006748   0.282635  0.805554          NaN
# ratingCount                   0.008588   0.285033  1.000000          NaN
# castNumber                   -0.010531   0.207761  0.057259          NaN
# companiesNumber               0.001378   0.088400  0.181193          NaN
# averageRating                 0.201996   0.020384  0.017673          NaN
# externalLinks                 0.008725   0.284752  0.551912          NaN
# writerCredits                -0.003100  -0.013233  0.018841          NaN
# directorsCredits             -0.049392  -0.000107  0.002145          NaN
# quotesTotal                  -0.053692   0.165021  0.363282          NaN
#
#                              bestRating  totalImages  totalVideos  \
# startYear                           NaN    -0.003611     0.027005
# awardWins                           NaN     0.198175     0.107434
# numVotes                            NaN     0.178825     0.161267
# worstRating                         NaN          NaN          NaN
# bestRating                          NaN          NaN          NaN
# totalImages                         NaN     1.000000     0.156272
# totalVideos                         NaN     0.156272     1.000000
# totalCredits                        NaN     0.337197     0.184727
# criticReviewsTotal                  NaN     0.171151     0.184913
# awardNominationsExcludeWins         NaN     0.313765     0.185887
# isAdult                             NaN    -0.012639    -0.006251
# numRegions                          NaN     0.212960     0.152611
# userReviewsTotal                    NaN     0.189283     0.191551
# ratingCount                         NaN     0.178850     0.161296
# castNumber                          NaN     0.339071     0.090532
# companiesNumber                     NaN     0.080383     0.057545
# averageRating                       NaN     0.004563    -0.003023
# externalLinks                       NaN     0.184599     0.176057
# writerCredits                       NaN    -0.006982    -0.003882
# directorsCredits                    NaN    -0.026878    -0.013703
# quotesTotal                         NaN     0.158750     0.098107
#
#                              totalCredits  criticReviewsTotal  \
# startYear                        0.069372            0.003592
# awardWins                        0.241754            0.306619
# numVotes                         0.196506            0.592157
# worstRating                           NaN                 NaN
# bestRating                            NaN                 NaN
# totalImages                      0.337197            0.171151
# totalVideos                      0.184727            0.184913
# totalCredits                     1.000000            0.250158
# criticReviewsTotal               0.250158            1.000000
# awardNominationsExcludeWins      0.374471            0.376330
# isAdult                         -0.032510           -0.011545
# numRegions                       0.260028            0.623800
# userReviewsTotal                 0.242667            0.603294
# ratingCount                      0.196533            0.592194
# castNumber                       0.834721            0.065201
# companiesNumber                  0.172313            0.262712
# averageRating                    0.015910           -0.040644
# externalLinks                    0.261326            0.917468
# writerCredits                    0.092481            0.040146
# directorsCredits                -0.000240            0.023240
# quotesTotal                      0.182091            0.379308
#
#                              awardNominationsExcludeWins  ...  numRegions  \
# startYear                                       0.035496  ...   -0.092510
# awardWins                                       0.726617  ...    0.227115
# numVotes                                        0.346974  ...    0.369382
# worstRating                                          NaN  ...         NaN
# bestRating                                           NaN  ...         NaN
# totalImages                                     0.313765  ...    0.212960
# totalVideos                                     0.185887  ...    0.152611
# totalCredits                                    0.374471  ...    0.260028
# criticReviewsTotal                              0.376330  ...    0.623800
# awardNominationsExcludeWins                     1.000000  ...    0.286857
# isAdult                                        -0.007184  ...   -0.028986
# numRegions                                      0.286857  ...    1.000000
# userReviewsTotal                                0.352352  ...    0.414432
# ratingCount                                     0.347061  ...    0.369388
# castNumber                                      0.328724  ...    0.153518
# companiesNumber                                 0.114300  ...    0.242122
# averageRating                                   0.010211  ...   -0.123117
# externalLinks                                   0.356401  ...    0.619503
# writerCredits                                  -0.014195  ...    0.020934
# directorsCredits                               -0.016055  ...    0.001501
# quotesTotal                                     0.228256  ...    0.363135
#
#                              userReviewsTotal  ratingCount  castNumber  \
# startYear                            0.006748     0.008588   -0.010531
# awardWins                            0.282635     0.285033    0.207761
# numVotes                             0.805554     1.000000    0.057259
# worstRating                               NaN          NaN         NaN
# bestRating                                NaN          NaN         NaN
# totalImages                          0.189283     0.178850    0.339071
# totalVideos                          0.191551     0.161296    0.090532
# totalCredits                         0.242667     0.196533    0.834721
# criticReviewsTotal                   0.603294     0.592194    0.065201
# awardNominationsExcludeWins          0.352352     0.347061    0.328724
# isAdult                             -0.009860    -0.007047   -0.009693
# numRegions                           0.414432     0.369388    0.153518
# userReviewsTotal                     1.000000     0.805606    0.068383
# ratingCount                          0.805606     1.000000    0.057266
# castNumber                           0.068383     0.057266    1.000000
# companiesNumber                      0.176353     0.181191    0.076224
# averageRating                       -0.004881     0.017677   -0.013437
# externalLinks                        0.557004     0.551935    0.082183
# writerCredits                        0.021710     0.018842   -0.016771
# directorsCredits                     0.000009     0.002143   -0.053851
# quotesTotal                          0.332745     0.363261    0.101475
#
#                              companiesNumber  averageRating  externalLinks  \
# startYear                           0.001378       0.201996       0.008725
# awardWins                           0.088400       0.020384       0.284752
# numVotes                            0.181193       0.017673       0.551912
# worstRating                              NaN            NaN            NaN
# bestRating                               NaN            NaN            NaN
# totalImages                         0.080383       0.004563       0.184599
# totalVideos                         0.057545      -0.003023       0.176057
# totalCredits                        0.172313       0.015910       0.261326
# criticReviewsTotal                  0.262712      -0.040644       0.917468
# awardNominationsExcludeWins         0.114300       0.010211       0.356401
# isAdult                            -0.021229      -0.073443      -0.026321
# numRegions                          0.242122      -0.123117       0.619503
# userReviewsTotal                    0.176353      -0.004881       0.557004
# ratingCount                         0.181191       0.017677       0.551935
# castNumber                          0.076224      -0.013437       0.082183
# companiesNumber                     1.000000      -0.015934       0.273427
# averageRating                      -0.015934       1.000000      -0.030992
# externalLinks                       0.273427      -0.030992       1.000000
# writerCredits                       0.064788       0.053686       0.067101
# directorsCredits                    0.030405      -0.009509       0.022510
# quotesTotal                         0.169154       0.031229       0.387281
#
#                              writerCredits  directorsCredits  quotesTotal
# startYear                        -0.003100         -0.049392    -0.053692
# awardWins                        -0.013233         -0.000107     0.165021
# numVotes                          0.018841          0.002145     0.363282
# worstRating                            NaN               NaN          NaN
# bestRating                             NaN               NaN          NaN
# totalImages                      -0.006982         -0.026878     0.158750
# totalVideos                      -0.003882         -0.013703     0.098107
# totalCredits                      0.092481         -0.000240     0.182091
# criticReviewsTotal                0.040146          0.023240     0.379308
# awardNominationsExcludeWins      -0.014195         -0.016055     0.228256
# isAdult                          -0.080015         -0.001846    -0.019316
# numRegions                        0.020934          0.001501     0.363135
# userReviewsTotal                  0.021710          0.000009     0.332745
# ratingCount                       0.018842          0.002143     0.363261
# castNumber                       -0.016771         -0.053851     0.101475
# companiesNumber                   0.064788          0.030405     0.169154
# averageRating                     0.053686         -0.009509     0.031229
# externalLinks                     0.067101          0.022510     0.387281
# writerCredits                     1.000000          0.269843     0.085269
# directorsCredits                  0.269843          1.000000     0.019854
# quotesTotal                       0.085269          0.019854     1.000000
#
# [21 rows x 21 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12,8))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Heatmap i Korrelacionit (Vetëm për Kolonat Numerike)")
plt.show()

# %%
print(df.shape)
# Out:
# (149531, 32)

# %%
# Zgjedh kolonat numerike
numerical_cols = df.select_dtypes(include=['float64', 'int64']).columns

# Histograma për kolonat numerike
plt.figure(figsize=(15, 10))
for i, col in enumerate(numerical_cols[:6]):
    plt.subplot(2, 3, i + 1)
    sns.histplot(df[col], bins=30, kde=True)
    plt.title(f'Distribution of {col}')
plt.tight_layout()
plt.show()

# %%
# Zgjedh kolonat kategorike
categorical_cols = df.select_dtypes(include=['object', 'category']).columns

# Barplot për 3 kolonat e para kategorike me pak kategori
plt.figure(figsize=(15, 5))
for i, col in enumerate(categorical_cols[:3]):
    if df[col].nunique() < 20:
        plt.subplot(1, 3, i + 1)
        df[col].value_counts().plot(kind='bar')
        plt.title(f'Value counts of {col}')
        plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 8))
corr = df[numerical_cols].corr()
sns.heatmap(corr, annot=True, fmt=".2f", cmap='coolwarm')
plt.title("Correlation Heatmap of Numerical Features")
plt.show()

# %%
df["worstRating"].value_counts()
# Out:
# worstRating
# 1    149531
# Name: count, dtype: int64

# %%
df["worstRating"].value_counts()
df["bestRating"].value_counts()
# Out:
# bestRating
# 10    149531
# Name: count, dtype: int64

# %%
df.drop(columns=["worstRating", "bestRating"], inplace=True)

# %%
df
# Out:
#                                   originalTitle  rating  startYear endYear  \
# 0                                    Carmencita  (5, 6]       1894      \N
# 1                                   Un bon bock  (5, 6]       1892      \N
# 2                             Chinese Opium Den  (4, 5]       1894      \N
# 3        Edison Kinetoscopic Record of a Sneeze  (5, 6]       1894      \N
# 4              L'arrivée d'un train à La Ciotat  (7, 8]       1896      \N
# ...                                         ...     ...        ...     ...
# 149526                         Nuestra película  (6, 7]       1993      \N
# 149527                                      Eco  (6, 7]       2019      \N
# 149528                  Women Take Center Stage  (5, 6]       2019      \N
# 149529  Horrid Henry and the Christening Crisis  (7, 8]       2011      \N
# 149530             A lenda do soprador de vidro  (8, 9]       2019      \N
#
#        runtimeMinutes  awardWins  numVotes  totalImages  totalVideos  \
# 0                   1          0      2089            2            0
# 1                  12          0       183            2            0
# 2                   1          0       195            1            0
# 3                   1          1      2237            3            0
# 4                   1          0     13115           12            0
# ...               ...        ...       ...          ...          ...
# 149526             96          0        11            0            0
# 149527             14          0        15            4            1
# 149528             \N          0        12            2            3
# 149529             10          0         9            1            0
# 149530             \N          0         9            3            0
#
#         totalCredits  ...                      genres castNumber  \
# 0                  4  ...           Documentary,Short          1
# 1                  2  ...             Animation,Short          0
# 2                  1  ...                       Short          0
# 3                  4  ...           Documentary,Short          1
# 4                 11  ...           Documentary,Short          6
# ...              ...  ...                         ...        ...
# 149526            11  ...                 Documentary          0
# 149527            52  ...                 Drama,Short          6
# 149528            32  ...                  Reality-TV          1
# 149529            15  ...  Adventure,Animation,Comedy          7
# 149530            33  ...                      Comedy          9
#
#         companiesNumber  averageRating  \
# 0                     3            5.7
# 1                     0            5.4
# 2                     1            5.0
# 3                     6            5.4
# 4                     5            7.4
# ...                 ...            ...
# 149526                2            7.0
# 149527                3            6.4
# 149528                0            5.6
# 149529                0            7.1
# 149530                0            8.6
#
#                                                   regions  externalLinks  \
# 0       ['\\N', 'DE', 'US', 'HU', 'GR', 'RU', 'UA', 'JP']              9
# 1             ['\\N', 'HU', 'DE', 'FR', 'RO', 'RU', 'JP']              3
# 2                   ['\\N', 'US', 'DE', 'PT', 'HU', 'RU']              4
# 3             ['\\N', 'UA', 'JP', 'HU', 'US', 'DE', 'RU']              6
# 4       ['\\N', 'HU', 'DE', 'TR', 'FI', 'FR', 'IT', 'E...             21
# ...                                                   ...            ...
# 149526                                      ['\\N', 'CO']              1
# 149527                                      ['\\N', 'ES']              5
# 149528                                            ['\\N']              0
# 149529                                            ['\\N']              0
# 149530                                            ['\\N']              0
#
#         writerCredits  directorsCredits  soundMixes quotesTotal
# 0                   0                 1  ['silent']           0
# 1                   0                 1  ['silent']           0
# 2                   0                 1  ['silent']           0
# 3                   0                 1  ['silent']           0
# 4                   0                 2  ['silent']           0
# ...               ...               ...         ...         ...
# 149526              1                 1          []           0
# 149527              1                 1          []           0
# 149528              0                 0          []           0
# 149529              3                 1          []           0
# 149530              3                 2          []           0
#
# [149531 rows x 30 columns]

# %%
df["endYear"].value_counts(dropna=False).head()
# Out:
# endYear
# \N      143897
# 2022       241
# 2017       222
# 2019       211
# 2018       206
# Name: count, dtype: int64

# %%
import numpy as np
# 1. Zëvendësojmë '\N' me NaN në 'endYear'
df["endYear"] = df["endYear"].replace("\\N", np.nan)


# 2. Konvertojmë 'endYear' në numerik (nga string), për të lejuar llogaritjet
df["endYear"] = pd.to_numeric(df["endYear"], errors="coerce")

# 3. Krijojmë kolonën e diferencës: sa vite zgjat (vetëm ku ka vlera të dyja)
df["durationYears"] = df["endYear"] - df["startYear"]

# 4. Llogarisim mesataren e diferencës së viteve
mean_duration = df["durationYears"].mean()

# 5. Plotësojmë vlerat mungesë të 'endYear' me (startYear + mesatarja)
mask_missing_end = df["endYear"].isna()
df.loc[mask_missing_end, "endYear"] = df.loc[mask_missing_end, "startYear"] + round(mean_duration)

# 6. Rillogarisim 'durationYears' me 'endYear' të përditësuar
df["durationYears"] = df["endYear"] - df["startYear"]

# 7. Heqim 'startYear' dhe 'endYear' nga dataseti për të reduktuar atributet
df.drop(columns=[ "endYear"], inplace=True)

# %%
df

# %%
df["endYear"].value_counts(dropna=False).head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'endYear'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 df["endYear"].value_counts(dropna=False).head()
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'endYear'

# %%
print(df["durationYears"].value_counts())
# Out:
# durationYears
# 2.0     144412
# 0.0       2480
# 1.0       1240
# 3.0        345
# 4.0        215
# 5.0        155
# 6.0        111
# 7.0         95
# 8.0         74
# 9.0         55
# 10.0        47
# 11.0        38
# 12.0        37
# 13.0        27
# 15.0        24
# 14.0        22
# 16.0        17
# 17.0        12
# 18.0        12
# 19.0        11
# 24.0         9
# 21.0         8
# 25.0         7
# 20.0         7
# 35.0         6
# 26.0         5
# 27.0         5
# 23.0         4
# 34.0         4
# 22.0         4
# 29.0         4
# 30.0         3
# 48.0         3
# 32.0         3
# 31.0         3
# 41.0         3
# 28.0         3
# 36.0         2
# 43.0         2
# 57.0         2
# 45.0         2
# 38.0         1
# 46.0         1
# 39.0         1
# 40.0         1
# 70.0         1
# 42.0         1
# 63.0         1
# 61.0         1
# 37.0         1
# 33.0         1
# 59.0         1
# 47.0         1
# 56.0         1
# Name: count, dtype: int64

# %%
print(df["soundMixes"].value_counts())
# Out:
# soundMixes
# []                                                                 96798
# ['mono']                                                           22813
# ['stereo']                                                         16725
# ['dolby_digital']                                                   4142
# ['silent']                                                          3293
#                                                                    ...
# ['dts', 'dolby', 'sdds', 'dolby_digital']                              1
# ['dolby', 'dts', 'sdds']                                               1
# ['animatophone', 'silent']                                             1
# ['dts', 'dolby_surround 7.1', 'dolby_digital', 'mono', 'dolby']        1
# ['dolby_digital', 'imax_6_track', 'dts', 'dolby_atmos']                1
# Name: count, Length: 305, dtype: int64

# %%
import numpy as np

# 1. Zëvendësojmë fillimisht [] me NaN për ta trajtuar më lehtë
df["soundMixes"] = df["soundMixes"].replace("[]", np.nan)

# 2. Krijojmë një grupim sipas disa kolonave që kanë kuptim për teknologjinë e zërit
group_cols = ["titleType", "genres", "startYear"]

# 3. Gjejmë modën e 'soundMixes' për çdo grupim
mode_per_group = (
    df.groupby(group_cols)["soundMixes"]
    .agg(lambda x: x.mode().iloc[0] if not x.mode().empty else np.nan)
    .reset_index()
    .rename(columns={"soundMixes": "most_common_mix"})
)

# 4. Bashkojmë këto moda përsëri te dataframe kryesor
df = df.merge(mode_per_group, on=group_cols, how="left")

# 5. Plotësojmë 'soundMixes' që janë NaN me modën e grupit
df["soundMixes"] = df["soundMixes"].fillna(df["most_common_mix"])

# 6. Heqim kolonën ndihmëse
df.drop(columns=["most_common_mix"], inplace=True)
df
# Out:
#                                   originalTitle  rating  startYear  \
# 0                                    Carmencita  (5, 6]       1894
# 1                                   Un bon bock  (5, 6]       1892
# 2                             Chinese Opium Den  (4, 5]       1894
# 3        Edison Kinetoscopic Record of a Sneeze  (5, 6]       1894
# 4              L'arrivée d'un train à La Ciotat  (7, 8]       1896
# ...                                         ...     ...        ...
# 149526                         Nuestra película  (6, 7]       1993
# 149527                                      Eco  (6, 7]       2019
# 149528                  Women Take Center Stage  (5, 6]       2019
# 149529  Horrid Henry and the Christening Crisis  (7, 8]       2011
# 149530             A lenda do soprador de vidro  (8, 9]       2019
#
#        runtimeMinutes  awardWins  numVotes  totalImages  totalVideos  \
# 0                   1          0      2089            2            0
# 1                  12          0       183            2            0
# 2                   1          0       195            1            0
# 3                   1          1      2237            3            0
# 4                   1          0     13115           12            0
# ...               ...        ...       ...          ...          ...
# 149526             96          0        11            0            0
# 149527             14          0        15            4            1
# 149528             \N          0        12            2            3
# 149529             10          0         9            1            0
# 149530             \N          0         9            3            0
#
#         totalCredits  criticReviewsTotal  ... castNumber  companiesNumber  \
# 0                  4                   3  ...          1                3
# 1                  2                   0  ...          0                0
# 2                  1                   0  ...          0                1
# 3                  4                   2  ...          1                6
# 4                 11                  16  ...          6                5
# ...              ...                 ...  ...        ...              ...
# 149526            11                   0  ...          0                2
# 149527            52                   1  ...          6                3
# 149528            32                   0  ...          1                0
# 149529            15                   0  ...          7                0
# 149530            33                   0  ...          9                0
#
#         averageRating                                            regions  \
# 0                 5.7  ['\\N', 'DE', 'US', 'HU', 'GR', 'RU', 'UA', 'JP']
# 1                 5.4        ['\\N', 'HU', 'DE', 'FR', 'RO', 'RU', 'JP']
# 2                 5.0              ['\\N', 'US', 'DE', 'PT', 'HU', 'RU']
# 3                 5.4        ['\\N', 'UA', 'JP', 'HU', 'US', 'DE', 'RU']
# 4                 7.4  ['\\N', 'HU', 'DE', 'TR', 'FI', 'FR', 'IT', 'E...
# ...               ...                                                ...
# 149526            7.0                                      ['\\N', 'CO']
# 149527            6.4                                      ['\\N', 'ES']
# 149528            5.6                                            ['\\N']
# 149529            7.1                                            ['\\N']
# 149530            8.6                                            ['\\N']
#
#         externalLinks  writerCredits  directorsCredits         soundMixes  \
# 0                   9              0                 1         ['silent']
# 1                   3              0                 1         ['silent']
# 2                   4              0                 1         ['silent']
# 3                   6              0                 1         ['silent']
# 4                  21              0                 2         ['silent']
# ...               ...            ...               ...                ...
# 149526              1              1                 1           ['mono']
# 149527              5              1                 1         ['stereo']
# 149528              0              0                 0  ['dolby_digital']
# 149529              0              3                 1         ['stereo']
# 149530              0              3                 2         ['stereo']
#
#        quotesTotal durationYears
# 0                0           2.0
# 1                0           2.0
# 2                0           2.0
# 3                0           2.0
# 4                0           2.0
# ...            ...           ...
# 149526           0           2.0
# 149527           0           2.0
# 149528           0           2.0
# 149529           0           2.0
# 149530           0           2.0
#
# [149531 rows x 30 columns]

# %%
print(df["soundMixes"].value_counts())
# Out:
# soundMixes
# ['stereo']                                                                              48218
# ['mono']                                                                                38872
# ['dolby_digital']                                                                       13458
# ['dolby']                                                                                4323
# ['silent']                                                                               3607
#                                                                                         ...
# ['dts_stereo', 'dts', 'dolby_sr']                                                           1
# ['dolby_atmos', 'd_cinema_48khz 5.1']                                                       1
# ['dts_es', '12_track_digital sound', 'auro_11.1', 'cinerama_7_track', 'dolby_atmos']        1
# ['dolby_digital', 'dts', 'sdds', 'dolby_atmos']                                             1
# ['dolby_digital', 'imax_6_track', 'dts', 'dolby_atmos']                                     1
# Name: count, Length: 304, dtype: int64

# %%
df.drop(columns=["worstRating", "bestRating"], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 df.drop(columns=["worstRating", "bestRating"], inplace=True)
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/generic.py:4788, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786 for axis, labels in axes.items():
#    4787     if labels is not None:
# -> 4788         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4790 if inplace:
#    4791     self._update_inplace(obj)
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/generic.py:4830, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4828         new_axis = axis.drop(labels, level=level, errors=errors)
#    4829     else:
# -> 4830         new_axis = axis.drop(labels, errors=errors)
#    4831     indexer = axis.get_indexer(new_axis)
#    4833 # Case for non-unique axis
#    4834 else:
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/indexes/base.py:7070, in Index.drop(self, labels, errors)
#    7068 if mask.any():
#    7069     if errors != "ignore":
# -> 7070         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071     indexer = indexer[~mask]
#    7072 return self.delete(indexer)
#
# KeyError: "['worstRating', 'bestRating'] not found in axis"

# %%
df
# Out:
#                                   originalTitle  rating  startYear  \
# 0                                    Carmencita  (5, 6]       1894
# 1                                   Un bon bock  (5, 6]       1892
# 2                             Chinese Opium Den  (4, 5]       1894
# 3        Edison Kinetoscopic Record of a Sneeze  (5, 6]       1894
# 4              L'arrivée d'un train à La Ciotat  (7, 8]       1896
# ...                                         ...     ...        ...
# 149526                         Nuestra película  (6, 7]       1993
# 149527                                      Eco  (6, 7]       2019
# 149528                  Women Take Center Stage  (5, 6]       2019
# 149529  Horrid Henry and the Christening Crisis  (7, 8]       2011
# 149530             A lenda do soprador de vidro  (8, 9]       2019
#
#        runtimeMinutes  awardWins  numVotes  totalImages  totalVideos  \
# 0                   1          0      2089            2            0
# 1                  12          0       183            2            0
# 2                   1          0       195            1            0
# 3                   1          1      2237            3            0
# 4                   1          0     13115           12            0
# ...               ...        ...       ...          ...          ...
# 149526             96          0        11            0            0
# 149527             14          0        15            4            1
# 149528             \N          0        12            2            3
# 149529             10          0         9            1            0
# 149530             \N          0         9            3            0
#
#         totalCredits  criticReviewsTotal  ... castNumber  companiesNumber  \
# 0                  4                   3  ...          1                3
# 1                  2                   0  ...          0                0
# 2                  1                   0  ...          0                1
# 3                  4                   2  ...          1                6
# 4                 11                  16  ...          6                5
# ...              ...                 ...  ...        ...              ...
# 149526            11                   0  ...          0                2
# 149527            52                   1  ...          6                3
# 149528            32                   0  ...          1                0
# 149529            15                   0  ...          7                0
# 149530            33                   0  ...          9                0
#
#         averageRating                                            regions  \
# 0                 5.7  ['\\N', 'DE', 'US', 'HU', 'GR', 'RU', 'UA', 'JP']
# 1                 5.4        ['\\N', 'HU', 'DE', 'FR', 'RO', 'RU', 'JP']
# 2                 5.0              ['\\N', 'US', 'DE', 'PT', 'HU', 'RU']
# 3                 5.4        ['\\N', 'UA', 'JP', 'HU', 'US', 'DE', 'RU']
# 4                 7.4  ['\\N', 'HU', 'DE', 'TR', 'FI', 'FR', 'IT', 'E...
# ...               ...                                                ...
# 149526            7.0                                      ['\\N', 'CO']
# 149527            6.4                                      ['\\N', 'ES']
# 149528            5.6                                            ['\\N']
# 149529            7.1                                            ['\\N']
# 149530            8.6                                            ['\\N']
#
#         externalLinks  writerCredits  directorsCredits         soundMixes  \
# 0                   9              0                 1         ['silent']
# 1                   3              0                 1         ['silent']
# 2                   4              0                 1         ['silent']
# 3                   6              0                 1         ['silent']
# 4                  21              0                 2         ['silent']
# ...               ...            ...               ...                ...
# 149526              1              1                 1           ['mono']
# 149527              5              1                 1         ['stereo']
# 149528              0              0                 0  ['dolby_digital']
# 149529              0              3                 1         ['stereo']
# 149530              0              3                 2         ['stereo']
#
#        quotesTotal durationYears
# 0                0           2.0
# 1                0           2.0
# 2                0           2.0
# 3                0           2.0
# 4                0           2.0
# ...            ...           ...
# 149526           0           2.0
# 149527           0           2.0
# 149528           0           2.0
# 149529           0           2.0
# 149530           0           2.0
#
# [149531 rows x 30 columns]

# %%
# Numërojmë sa herë shfaqet '\N'
runtime_null_like = (df["runtimeMinutes"] == "\\N").sum()
print(f"Numri i vlerave '\\N' në 'runtimeMinutes': {runtime_null_like}")
# Out:
# Numri i vlerave '\N' në 'runtimeMinutes': 40195

# %%
# Sigurohemi që runtimeMinutes është numerik
df["runtimeMinutes"] = pd.to_numeric(df["runtimeMinutes"], errors="coerce")

# Lista e të gjitha kolonave numerike, përfshirë runtimeMinutes
numeric_cols = df.select_dtypes(include=["int64", "float64"]).columns

# Korrelacioni i runtimeMinutes me të gjitha kolonat numerike
runtime_corr = df[numeric_cols].corr()["runtimeMinutes"].drop("runtimeMinutes").sort_values(ascending=False)
runtime_corr.head(10)
# Out:
# numRegions            0.272550
# criticReviewsTotal    0.150129
# externalLinks         0.143805
# isAdult               0.101524
# userReviewsTotal      0.082351
# companiesNumber       0.079583
# castNumber            0.063655
# awardWins             0.063172
# numVotes              0.063016
# ratingCount           0.063016
# Name: runtimeMinutes, dtype: float64

# %%
df["runtimeMinutes"] = df.groupby("titleType")["runtimeMinutes"].transform(
    lambda x: x.fillna(x.median())
)

# %%
df
# Out:
#                                   originalTitle  rating  startYear  \
# 0                                    Carmencita  (5, 6]       1894
# 1                                   Un bon bock  (5, 6]       1892
# 2                             Chinese Opium Den  (4, 5]       1894
# 3        Edison Kinetoscopic Record of a Sneeze  (5, 6]       1894
# 4              L'arrivée d'un train à La Ciotat  (7, 8]       1896
# ...                                         ...     ...        ...
# 149526                         Nuestra película  (6, 7]       1993
# 149527                                      Eco  (6, 7]       2019
# 149528                  Women Take Center Stage  (5, 6]       2019
# 149529  Horrid Henry and the Christening Crisis  (7, 8]       2011
# 149530             A lenda do soprador de vidro  (8, 9]       2019
#
#         runtimeMinutes  awardWins  numVotes  totalImages  totalVideos  \
# 0                  1.0          0      2089            2            0
# 1                 12.0          0       183            2            0
# 2                  1.0          0       195            1            0
# 3                  1.0          1      2237            3            0
# 4                  1.0          0     13115           12            0
# ...                ...        ...       ...          ...          ...
# 149526            96.0          0        11            0            0
# 149527            14.0          0        15            4            1
# 149528            30.0          0        12            2            3
# 149529            10.0          0         9            1            0
# 149530            30.0          0         9            3            0
#
#         totalCredits  criticReviewsTotal  ... castNumber  companiesNumber  \
# 0                  4                   3  ...          1                3
# 1                  2                   0  ...          0                0
# 2                  1                   0  ...          0                1
# 3                  4                   2  ...          1                6
# 4                 11                  16  ...          6                5
# ...              ...                 ...  ...        ...              ...
# 149526            11                   0  ...          0                2
# 149527            52                   1  ...          6                3
# 149528            32                   0  ...          1                0
# 149529            15                   0  ...          7                0
# 149530            33                   0  ...          9                0
#
#         averageRating                                            regions  \
# 0                 5.7  ['\\N', 'DE', 'US', 'HU', 'GR', 'RU', 'UA', 'JP']
# 1                 5.4        ['\\N', 'HU', 'DE', 'FR', 'RO', 'RU', 'JP']
# 2                 5.0              ['\\N', 'US', 'DE', 'PT', 'HU', 'RU']
# 3                 5.4        ['\\N', 'UA', 'JP', 'HU', 'US', 'DE', 'RU']
# 4                 7.4  ['\\N', 'HU', 'DE', 'TR', 'FI', 'FR', 'IT', 'E...
# ...               ...                                                ...
# 149526            7.0                                      ['\\N', 'CO']
# 149527            6.4                                      ['\\N', 'ES']
# 149528            5.6                                            ['\\N']
# 149529            7.1                                            ['\\N']
# 149530            8.6                                            ['\\N']
#
#         externalLinks  writerCredits  directorsCredits         soundMixes  \
# 0                   9              0                 1         ['silent']
# 1                   3              0                 1         ['silent']
# 2                   4              0                 1         ['silent']
# 3                   6              0                 1         ['silent']
# 4                  21              0                 2         ['silent']
# ...               ...            ...               ...                ...
# 149526              1              1                 1           ['mono']
# 149527              5              1                 1         ['stereo']
# 149528              0              0                 0  ['dolby_digital']
# 149529              0              3                 1         ['stereo']
# 149530              0              3                 2         ['stereo']
#
#        quotesTotal durationYears
# 0                0           2.0
# 1                0           2.0
# 2                0           2.0
# 3                0           2.0
# 4                0           2.0
# ...            ...           ...
# 149526           0           2.0
# 149527           0           2.0
# 149528           0           2.0
# 149529           0           2.0
# 149530           0           2.0
#
# [149531 rows x 30 columns]

# %%
df.shape
# Out:
# (149531, 30)

# %%
##heqja e \N ku ka [\N] dhe vendosja Uknown ndersa ku ka [\N dhe emer] lejme vetem emrin

# %%
# 1. Hiq çdo '\N' në mënyrë më të fortë dhe të përgjithshme
df["regions"] = df["regions"].astype(str).str.replace(r"'\\N'\s*,?\s*", "", regex=True)

# 2. Nëse mbetet bosh, vendos ['Unknown']
df["regions"] = df["regions"].replace(r"\[\s*\]", "['Unknown']", regex=True)

# %%
df
# Out:
#                                   originalTitle  rating  startYear  \
# 0                                    Carmencita  (5, 6]       1894
# 1                                   Un bon bock  (5, 6]       1892
# 2                             Chinese Opium Den  (4, 5]       1894
# 3        Edison Kinetoscopic Record of a Sneeze  (5, 6]       1894
# 4              L'arrivée d'un train à La Ciotat  (7, 8]       1896
# ...                                         ...     ...        ...
# 149526                         Nuestra película  (6, 7]       1993
# 149527                                      Eco  (6, 7]       2019
# 149528                  Women Take Center Stage  (5, 6]       2019
# 149529  Horrid Henry and the Christening Crisis  (7, 8]       2011
# 149530             A lenda do soprador de vidro  (8, 9]       2019
#
#         runtimeMinutes  awardWins  numVotes  totalImages  totalVideos  \
# 0                  1.0          0      2089            2            0
# 1                 12.0          0       183            2            0
# 2                  1.0          0       195            1            0
# 3                  1.0          1      2237            3            0
# 4                  1.0          0     13115           12            0
# ...                ...        ...       ...          ...          ...
# 149526            96.0          0        11            0            0
# 149527            14.0          0        15            4            1
# 149528            30.0          0        12            2            3
# 149529            10.0          0         9            1            0
# 149530            30.0          0         9            3            0
#
#         totalCredits  criticReviewsTotal  ... castNumber  companiesNumber  \
# 0                  4                   3  ...          1                3
# 1                  2                   0  ...          0                0
# 2                  1                   0  ...          0                1
# 3                  4                   2  ...          1                6
# 4                 11                  16  ...          6                5
# ...              ...                 ...  ...        ...              ...
# 149526            11                   0  ...          0                2
# 149527            52                   1  ...          6                3
# 149528            32                   0  ...          1                0
# 149529            15                   0  ...          7                0
# 149530            33                   0  ...          9                0
#
#         averageRating                                            regions  \
# 0                 5.7  ['\\N', 'DE', 'US', 'HU', 'GR', 'RU', 'UA', 'JP']
# 1                 5.4        ['\\N', 'HU', 'DE', 'FR', 'RO', 'RU', 'JP']
# 2                 5.0              ['\\N', 'US', 'DE', 'PT', 'HU', 'RU']
# 3                 5.4        ['\\N', 'UA', 'JP', 'HU', 'US', 'DE', 'RU']
# 4                 7.4  ['\\N', 'HU', 'DE', 'TR', 'FI', 'FR', 'IT', 'E...
# ...               ...                                                ...
# 149526            7.0                                      ['\\N', 'CO']
# 149527            6.4                                      ['\\N', 'ES']
# 149528            5.6                                            ['\\N']
# 149529            7.1                                            ['\\N']
# 149530            8.6                                            ['\\N']
#
#         externalLinks  writerCredits  directorsCredits         soundMixes  \
# 0                   9              0                 1         ['silent']
# 1                   3              0                 1         ['silent']
# 2                   4              0                 1         ['silent']
# 3                   6              0                 1         ['silent']
# 4                  21              0                 2         ['silent']
# ...               ...            ...               ...                ...
# 149526              1              1                 1           ['mono']
# 149527              5              1                 1         ['stereo']
# 149528              0              0                 0  ['dolby_digital']
# 149529              0              3                 1         ['stereo']
# 149530              0              3                 2         ['stereo']
#
#        quotesTotal durationYears
# 0                0           2.0
# 1                0           2.0
# 2                0           2.0
# 3                0           2.0
# 4                0           2.0
# ...            ...           ...
# 149526           0           2.0
# 149527           0           2.0
# 149528           0           2.0
# 149529           0           2.0
# 149530           0           2.0
#
# [149531 rows x 30 columns]

# %%
df["regions"].sample
# Out:
# <bound method NDFrame.sample of 0                ['DE', 'US', 'HU', 'GR', 'RU', 'UA', 'JP']
# 1                      ['HU', 'DE', 'FR', 'RO', 'RU', 'JP']
# 2                            ['US', 'DE', 'PT', 'HU', 'RU']
# 3                      ['UA', 'JP', 'HU', 'US', 'DE', 'RU']
# 4         ['HU', 'DE', 'TR', 'FI', 'FR', 'IT', 'ES', 'SK...
#                                 ...
# 149526                                               ['CO']
# 149527                                               ['ES']
# 149528                                          ['Unknown']
# 149529                                          ['Unknown']
# 149530                                          ['Unknown']
# Name: regions, Length: 149531, dtype: object>

# %%
import ast

def clean_regions(val):
    try:
        region_list = ast.literal_eval(val)
        region_list = [r for r in region_list if r != '\\N']
        return str(region_list if region_list else ['Unknown'])
    except:
        return "['Unknown']"

# Apliko funksionin për çdo vlerë në kolonën 'regions'
df["regions"] = df["regions"].astype(str).apply(clean_regions)

# %%
df
# Out:
#                                   originalTitle  rating  startYear  \
# 0                                    Carmencita  (5, 6]       1894
# 1                                   Un bon bock  (5, 6]       1892
# 2                             Chinese Opium Den  (4, 5]       1894
# 3        Edison Kinetoscopic Record of a Sneeze  (5, 6]       1894
# 4              L'arrivée d'un train à La Ciotat  (7, 8]       1896
# ...                                         ...     ...        ...
# 149526                         Nuestra película  (6, 7]       1993
# 149527                                      Eco  (6, 7]       2019
# 149528                  Women Take Center Stage  (5, 6]       2019
# 149529  Horrid Henry and the Christening Crisis  (7, 8]       2011
# 149530             A lenda do soprador de vidro  (8, 9]       2019
#
#         runtimeMinutes  awardWins  numVotes  totalImages  totalVideos  \
# 0                  1.0          0      2089            2            0
# 1                 12.0          0       183            2            0
# 2                  1.0          0       195            1            0
# 3                  1.0          1      2237            3            0
# 4                  1.0          0     13115           12            0
# ...                ...        ...       ...          ...          ...
# 149526            96.0          0        11            0            0
# 149527            14.0          0        15            4            1
# 149528            30.0          0        12            2            3
# 149529            10.0          0         9            1            0
# 149530            30.0          0         9            3            0
#
#         totalCredits  criticReviewsTotal  ... castNumber  companiesNumber  \
# 0                  4                   3  ...          1                3
# 1                  2                   0  ...          0                0
# 2                  1                   0  ...          0                1
# 3                  4                   2  ...          1                6
# 4                 11                  16  ...          6                5
# ...              ...                 ...  ...        ...              ...
# 149526            11                   0  ...          0                2
# 149527            52                   1  ...          6                3
# 149528            32                   0  ...          1                0
# 149529            15                   0  ...          7                0
# 149530            33                   0  ...          9                0
#
#         averageRating                                            regions  \
# 0                 5.7         ['DE', 'US', 'HU', 'GR', 'RU', 'UA', 'JP']
# 1                 5.4               ['HU', 'DE', 'FR', 'RO', 'RU', 'JP']
# 2                 5.0                     ['US', 'DE', 'PT', 'HU', 'RU']
# 3                 5.4               ['UA', 'JP', 'HU', 'US', 'DE', 'RU']
# 4                 7.4  ['HU', 'DE', 'TR', 'FI', 'FR', 'IT', 'ES', 'SK...
# ...               ...                                                ...
# 149526            7.0                                             ['CO']
# 149527            6.4                                             ['ES']
# 149528            5.6                                        ['Unknown']
# 149529            7.1                                        ['Unknown']
# 149530            8.6                                        ['Unknown']
#
#         externalLinks  writerCredits  directorsCredits         soundMixes  \
# 0                   9              0                 1         ['silent']
# 1                   3              0                 1         ['silent']
# 2                   4              0                 1         ['silent']
# 3                   6              0                 1         ['silent']
# 4                  21              0                 2         ['silent']
# ...               ...            ...               ...                ...
# 149526              1              1                 1           ['mono']
# 149527              5              1                 1         ['stereo']
# 149528              0              0                 0  ['dolby_digital']
# 149529              0              3                 1         ['stereo']
# 149530              0              3                 2         ['stereo']
#
#        quotesTotal durationYears
# 0                0           2.0
# 1                0           2.0
# 2                0           2.0
# 3                0           2.0
# 4                0           2.0
# ...            ...           ...
# 149526           0           2.0
# 149527           0           2.0
# 149528           0           2.0
# 149529           0           2.0
# 149530           0           2.0
#
# [149531 rows x 30 columns]

# %%
df["regions"].value_counts()
# Out:
# regions
# ['Unknown']                                                                          34824
# ['US']                                                                               31354
# ['PT', 'IN', 'FR', 'IT', 'DE', 'JP', 'ES']                                            8108
# ['GB']                                                                                6859
# ['JP']                                                                                3049
#                                                                                      ...
# ['ES', 'EC', 'GB', 'IT', 'US', 'BG', 'SUHH', 'BR', 'XWG']                                1
# ['MX', 'BR', 'SUHH', 'CA', 'GB', 'IT', 'US', 'AR', 'FI', 'XWG']                          1
# ['GR', 'XWG', 'ES', 'PL', 'AR', 'SUHH', 'CA', 'US', 'FR', 'BR', 'NO', 'SE', 'IT']        1
# ['FI', 'JP', 'SUHH', 'FR', 'US', 'CA', 'PL', 'XWG', 'ES']                                1
# ['UA', 'RU', 'SUHH', 'IT', 'GB', 'US', 'XWW', 'SE']                                      1
# Name: count, Length: 26135, dtype: int64

# %%
    import matplotlib.pyplot as plt
    import seaborn as sns
    
    # 1. Zgjedhim vetëm kolonat numerike
numeric_df = df.select_dtypes(include=["int64", "float64"])

# 2. Llogarisim matricën e korrelacionit
correlation_matrix = numeric_df.corr()

# 3. Vizualizojmë si heatmap
plt.figure(figsize=(16, 12))
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap="coolwarm", square=True)
plt.title("Correlation Matrix - Numerical Features", fontsize=16)
plt.xticks(rotation=45)
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df, x="numVotes", y="ratingCount")
plt.title("numVotes vs ratingCount")
plt.xlabel("numVotes")
plt.ylabel("ratingCount")
plt.show()

# %%
df.drop(columns=["numVotes", "castNumber", "externalLinks", "userReviewsTotal"], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[139], line 1
# ----> 1 df.drop(columns=["numVotes", "castNumber", "externalLinks", "userReviewsTotal"], inplace=True)
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/generic.py:4788, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786 for axis, labels in axes.items():
#    4787     if labels is not None:
# -> 4788         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4790 if inplace:
#    4791     self._update_inplace(obj)
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/generic.py:4830, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4828         new_axis = axis.drop(labels, level=level, errors=errors)
#    4829     else:
# -> 4830         new_axis = axis.drop(labels, errors=errors)
#    4831     indexer = axis.get_indexer(new_axis)
#    4833 # Case for non-unique axis
#    4834 else:
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/indexes/base.py:7070, in Index.drop(self, labels, errors)
#    7068 if mask.any():
#    7069     if errors != "ignore":
# -> 7070         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071     indexer = indexer[~mask]
#    7072 return self.delete(indexer)
#
# KeyError: "['numVotes', 'castNumber', 'externalLinks'] not found in axis"

# %%
df
# Out:
#                                   originalTitle  rating  startYear  \
# 0                                    Carmencita  (5, 6]       1894
# 1                                   Un bon bock  (5, 6]       1892
# 2                             Chinese Opium Den  (4, 5]       1894
# 3        Edison Kinetoscopic Record of a Sneeze  (5, 6]       1894
# 4              L'arrivée d'un train à La Ciotat  (7, 8]       1896
# ...                                         ...     ...        ...
# 149526                         Nuestra película  (6, 7]       1993
# 149527                                      Eco  (6, 7]       2019
# 149528                  Women Take Center Stage  (5, 6]       2019
# 149529  Horrid Henry and the Christening Crisis  (7, 8]       2011
# 149530             A lenda do soprador de vidro  (8, 9]       2019
#
#         runtimeMinutes  awardWins  totalImages  totalVideos  totalCredits  \
# 0                  1.0          0            2            0             4
# 1                 12.0          0            2            0             2
# 2                  1.0          0            1            0             1
# 3                  1.0          1            3            0             4
# 4                  1.0          0           12            0            11
# ...                ...        ...          ...          ...           ...
# 149526            96.0          0            0            0            11
# 149527            14.0          0            4            1            52
# 149528            30.0          0            2            3            32
# 149529            10.0          0            1            0            15
# 149530            30.0          0            3            0            33
#
#         criticReviewsTotal  titleType  ...  countryOfOrigin  \
# 0                        3      short  ...           ['US']
# 1                        0      short  ...           ['FR']
# 2                        0      short  ...           ['US']
# 3                        2      short  ...           ['US']
# 4                       16      short  ...           ['FR']
# ...                    ...        ...  ...              ...
# 149526                   0      movie  ...           ['CO']
# 149527                   1      short  ...           ['ES']
# 149528                   0  tvEpisode  ...              NaN
# 149529                   0  tvEpisode  ...              NaN
# 149530                   0  tvEpisode  ...              NaN
#
#                             genres  companiesNumber  averageRating  \
# 0                Documentary,Short                3            5.7
# 1                  Animation,Short                0            5.4
# 2                            Short                1            5.0
# 3                Documentary,Short                6            5.4
# 4                Documentary,Short                5            7.4
# ...                            ...              ...            ...
# 149526                 Documentary                2            7.0
# 149527                 Drama,Short                3            6.4
# 149528                  Reality-TV                0            5.6
# 149529  Adventure,Animation,Comedy                0            7.1
# 149530                      Comedy                0            8.6
#
#                                                   regions  writerCredits  \
# 0              ['DE', 'US', 'HU', 'GR', 'RU', 'UA', 'JP']              0
# 1                    ['HU', 'DE', 'FR', 'RO', 'RU', 'JP']              0
# 2                          ['US', 'DE', 'PT', 'HU', 'RU']              0
# 3                    ['UA', 'JP', 'HU', 'US', 'DE', 'RU']              0
# 4       ['HU', 'DE', 'TR', 'FI', 'FR', 'IT', 'ES', 'SK...              0
# ...                                                   ...            ...
# 149526                                             ['CO']              1
# 149527                                             ['ES']              1
# 149528                                        ['Unknown']              0
# 149529                                        ['Unknown']              3
# 149530                                        ['Unknown']              3
#
#         directorsCredits         soundMixes quotesTotal  durationYears
# 0                      1         ['silent']           0            2.0
# 1                      1         ['silent']           0            2.0
# 2                      1         ['silent']           0            2.0
# 3                      1         ['silent']           0            2.0
# 4                      2         ['silent']           0            2.0
# ...                  ...                ...         ...            ...
# 149526                 1           ['mono']           0            2.0
# 149527                 1         ['stereo']           0            2.0
# 149528                 0  ['dolby_digital']           0            2.0
# 149529                 1         ['stereo']           0            2.0
# 149530                 2         ['stereo']           0            2.0
#
# [149531 rows x 27 columns]

# %%
df.drop(columns=["userReviewsTotal"], inplace=True)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# 1. Zgjedhim vetëm kolonat numerike
numeric_df = df.select_dtypes(include=["int64", "float64"])

# 2. Llogarisim matricën e korrelacionit
correlation_matrix = numeric_df.corr()

# 3. Vizualizojmë si heatmap
plt.figure(figsize=(16, 12))
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap="coolwarm", square=True)
plt.title("Correlation Matrix - Numerical Features", fontsize=16)
plt.xticks(rotation=45)
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
df.shape
# Out:
# (149531, 26)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Zgjedhim vetëm kolonat numerike
numeric_df = df.select_dtypes(include=["int64", "float64"])

# Pairplot për të gjitha veçoritë numerike
sns.pairplot(numeric_df, corner=True, plot_kws={"alpha": 0.5, "s": 15})
plt.suptitle("Pairplot of Numerical Features", y=1.02)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[149], line 8
#       5 numeric_df = df.select_dtypes(include=["int64", "float64"])
#       7 # Pairplot për të gjitha veçoritë numerike
# ----> 8 sns.pairplot(numeric_df, corner=True, plot_kws={"alpha": 0.5, "s": 15})
#       9 plt.suptitle("Pairplot of Numerical Features", y=1.02)
#      10 plt.show()
#
# File /opt/anaconda3/lib/python3.12/site-packages/seaborn/axisgrid.py:2149, in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    2147 diag_kws.setdefault("legend", False)
#    2148 if diag_kind == "hist":
# -> 2149     grid.map_diag(histplot, **diag_kws)
#    2150 elif diag_kind == "kde":
#    2151     diag_kws.setdefault("fill", True)
#
# File /opt/anaconda3/lib/python3.12/site-packages/seaborn/axisgrid.py:1513, in PairGrid.map_diag(self, func, **kwargs)
#    1511     plot_kwargs.setdefault("hue_order", self._hue_order)
#    1512     plot_kwargs.setdefault("palette", self._orig_palette)
# -> 1513     func(x=vector, **plot_kwargs)
#    1514     ax.legend_ = None
#    1516 self._add_axis_labels()
#
# File /opt/anaconda3/lib/python3.12/site-packages/seaborn/distributions.py:1416, in histplot(data, x, y, hue, weights, stat, bins, binwidth, binrange, discrete, cumulative, common_bins, common_norm, multiple, element, fill, shrink, kde, kde_kws, line_kws, thresh, pthresh, pmax, cbar, cbar_ax, cbar_kws, palette, hue_order, hue_norm, color, log_scale, legend, ax, **kwargs)
#    1405 estimate_kws = dict(
#    1406     stat=stat,
#    1407     bins=bins,
#    (...)
#    1411     cumulative=cumulative,
#    1412 )
#    1414 if p.univariate:
# -> 1416     p.plot_univariate_histogram(
#    1417         multiple=multiple,
#    1418         element=element,
#    1419         fill=fill,
#    1420         shrink=shrink,
#    1421         common_norm=common_norm,
#    1422         common_bins=common_bins,
#    1423         kde=kde,
#    1424         kde_kws=kde_kws,
#    1425         color=color,
#    1426         legend=legend,
#    1427         estimate_kws=estimate_kws,
#    1428         line_kws=line_kws,
#    1429         **kwargs,
#    1430     )
#    1432 else:
#    1434     p.plot_bivariate_histogram(
#    1435         common_bins=common_bins,
#    1436         common_norm=common_norm,
#    (...)
#    1446         **kwargs,
#    1447     )
#
# File /opt/anaconda3/lib/python3.12/site-packages/seaborn/distributions.py:571, in _DistributionPlotter.plot_univariate_histogram(self, multiple, element, fill, common_norm, common_bins, shrink, kde, kde_kws, color, legend, line_kws, estimate_kws, **plot_kws)
#     566 if element == "bars":
#     567
#     568     # Use matplotlib bar plotting
#     570     plot_func = ax.bar if self.data_variable == "x" else ax.barh
# --> 571     artists = plot_func(
#     572         hist["edges"],
#     573         hist["heights"] - bottom,
#     574         hist["widths"],
#     575         bottom,
#     576         align="edge",
#     577         **artist_kws,
#     578     )
#     580     for bar in artists:
#     581         if self.data_variable == "x":
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/__init__.py:1473, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1470 @functools.wraps(func)
#    1471 def inner(ax, *args, data=None, **kwargs):
#    1472     if data is None:
# -> 1473         return func(
#    1474             ax,
#    1475             *map(sanitize_sequence, args),
#    1476             **{k: sanitize_sequence(v) for k, v in kwargs.items()})
#    1478     bound = new_sig.bind(ax, *args, **kwargs)
#    1479     auto_label = (bound.arguments.get(label_namer)
#    1480                   or bound.kwargs.get(label_namer))
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/axes/_axes.py:2597, in Axes.bar(self, x, height, width, bottom, align, **kwargs)
#    2595     else:  # horizontal
#    2596         r.sticky_edges.x.append(l)
# -> 2597     self.add_patch(r)
#    2598     patches.append(r)
#    2600 if xerr is not None or yerr is not None:
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/axes/_base.py:2414, in _AxesBase.add_patch(self, p)
#    2412 if p.get_clip_path() is None:
#    2413     p.set_clip_path(self.patch)
# -> 2414 self._update_patch_limits(p)
#    2415 self._children.append(p)
#    2416 p._remove_method = self._children.remove
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/axes/_base.py:2446, in _AxesBase._update_patch_limits(self, patch)
#    2443     vertices = np.vstack(vertices)
#    2445 patch_trf = patch.get_transform()
# -> 2446 updatex, updatey = patch_trf.contains_branch_seperately(self.transData)
#    2447 if not (updatex or updatey):
#    2448     return
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/transforms.py:2407, in CompositeGenericTransform.contains_branch_seperately(self, other_transform)
#    2404     for left, right in self._b._iter_break_from_left_to_right():
#    2405         yield self._a + left, right
# -> 2407 def contains_branch_seperately(self, other_transform):
#    2408     # docstring inherited
#    2409     if self.output_dims != 2:
#    2410         raise ValueError('contains_branch_seperately only supports '
#    2411                          'transforms with 2 output dimensions')
#
# KeyboardInterrupt:

# %%
# Ruaj datasetin e modifikuar në një file të ri CSV
df.to_csv("imdb_cleaned.csv", index=False)

# %%
from sklearn.model_selection import train_test_split

# Zgjedhim veçoritë numerike
numerical_cols = df.select_dtypes(include=["int64", "float64"]).columns

# Supozojmë që do përdorësh gjithë datasetin për tani (pa target ende)
X = df[numerical_cols]  # input features

# Ndajmë në train/test (p.sh. 80/20)
X_train, X_test = train_test_split(X, test_size=0.2, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)  # llogarit mesatare/std në train
X_test_scaled = scaler.transform(X_test)        # aplikon të njëjtat rregulla te test

# %%
from collections import Counter
import seaborn as sns
import matplotlib.pyplot as plt

# Krijojmë një listë me të gjitha zhanret individuale
all_genres = df["genres"].dropna().str.split(",").sum()  # ndan dhe bashkon të gjitha
genre_counts = Counter(all_genres)

# Kthejmë në DataFrame për vizualizim
genre_df = pd.DataFrame.from_dict(genre_counts, orient="index", columns=["count"])
genre_df = genre_df.sort_values("count", ascending=False)

# Vizualizim si barplot
plt.figure(figsize=(12, 6))
sns.barplot(x=genre_df.index, y=genre_df["count"], palette="viridis")
plt.title("Shpërndarja e zhanreve (genres)")
plt.xticks(rotation=45)
plt.ylabel("Numri i titujve")
plt.xlabel("Zhanri")
plt.tight_layout()
plt.show()
# Out:
# /var/folders/gz/31s52hw53h989n3kw4dfw2fm0000gn/T/ipykernel_24406/696249115.py:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=genre_df.index, y=genre_df["count"], palette="viridis")

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Histogramë për shpërndarjen e 'isAdult'
plt.figure(figsize=(6, 4))
sns.countplot(x='isAdult', data=df, palette='Set2')
plt.title("Distribucioni i vlerave në 'isAdult'")
plt.xlabel("isAdult (0 = Jo Adult, 1 = Adult)")
plt.ylabel("Numri i titujve")
plt.xticks([0, 1], ['Jo Adult', 'Adult'])
plt.tight_layout()
plt.show()
# Out:
# /var/folders/gz/31s52hw53h989n3kw4dfw2fm0000gn/T/ipykernel_24406/3138005963.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='isAdult', data=df, palette='Set2')

# %%
# Numërojmë sa tituj janë për çdo klasë në 'isAdult'
isadult_counts = df["isAdult"].value_counts()

# Printojmë rezultatin bukur
print(f"Jo Adult (0): {isadult_counts.get(0, 0)} tituj")
print(f"Adult (1): {isadult_counts.get(1, 0)} tituj")
# Out:
# Jo Adult (0): 146798 tituj
# Adult (1): 2733 tituj

# %%
2733/146798
# Out:
# 0.018617419855856347

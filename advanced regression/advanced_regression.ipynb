# %%
import pandas as pd
import matplotlib.pyplot as plt
 
 
df=pd.read_csv('imdb_cleaned_finale.csv')

# %%
# 1. Importimi i librarive
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import pandas as pd
import numpy as np


# 3. Përzgjedhja e input features dhe target
feature_cols = [
    'runtimeMinutes', 
    'ratingCount', 
    'awardWins', 
    'companiesNumber', 
    'writerCredits', 
    'directorsCredits', 
    'totalImages', 
    'totalVideos', 
    'quotesTotal', 
    'durationYears'
]

X = df[feature_cols]
y = df['averageRating']

# 4. Ndajmë në train/test sets (70% train, 30% test)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# 5. Definimi i Random Forest dhe parametrat për GridSearch
param_grid = {
    'n_estimators': [100],  # Zvogëlojmë pak për laptop të lehtë
    'max_depth': [None],
    'min_samples_split': [2]
}

rf = RandomForestRegressor(random_state=42)

# 6. GridSearchCV (me n_jobs=1 për më shumë stabilitet në MacBook Air)
grid_search_rf = GridSearchCV(
    estimator=rf,
    param_grid=param_grid,
    cv=5,
    scoring='neg_mean_absolute_error',
    n_jobs=1  # Një CPU core, për të mos e ngarkuar shumë
)

# 7. Trajno modelin
grid_search_rf.fit(X_train, y_train)

# 8. Modeli më i mirë
best_rf = grid_search_rf.best_estimator_

# 9. Predikto mbi test set
y_pred = best_rf.predict(X_test)

# 10. Llogarit metrikat
mae = mean_absolute_error(y_test, y_pred)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
r2 = r2_score(y_test, y_pred)

# 11. Printo rezultatet
print("\n========== Random Forest Regressor Results ==========")
print(f"Best Parameters: {grid_search_rf.best_params_}")
print(f"Mean Absolute Error (MAE): {mae:.4f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.4f}")
print(f"R² Score: {r2:.4f}")
print("======================================================")
# Out:
# ========== Random Forest Regressor Results ==========
# Best Parameters: {'max_depth': None, 'min_samples_split': 2, 'n_estimators': 100}
# Mean Absolute Error (MAE): 0.9152
# Root Mean Squared Error (RMSE): 1.2387
# R² Score: 0.1554
# ...

# %%
# 1. Importimi i librarive
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import pandas as pd
import numpy as np


# 3. Përzgjedhja e input features dhe target
feature_cols = [
    'runtimeMinutes', 
    'ratingCount', 
    'awardWins', 
    'companiesNumber', 
    'writerCredits', 
    'directorsCredits', 
    'totalImages', 
    'totalVideos', 
    'quotesTotal', 
    'durationYears'
]

X = df[feature_cols]
y = df['averageRating']

# 4. Ndajmë në train/test sets (70% train, 30% test)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# 5. Definimi i Random Forest dhe parametrat për GridSearch
param_grid = {
    'n_estimators': [10],  # Zvogëlojmë pak për laptop të lehtë
    'max_depth': [None],
    'min_samples_split': [2]
}

rf = RandomForestRegressor(random_state=42)

# 6. GridSearchCV (me n_jobs=1 për më shumë stabilitet në MacBook Air)
grid_search_rf = GridSearchCV(
    estimator=rf,
    param_grid=param_grid,
    cv=5,
    scoring='neg_mean_absolute_error',
    n_jobs=1  # Një CPU core, për të mos e ngarkuar shumë
)

# 7. Trajno modelin
grid_search_rf.fit(X_train, y_train)

# 8. Modeli më i mirë
best_rf = grid_search_rf.best_estimator_

# 9. Predikto mbi test set
y_pred = best_rf.predict(X_test)

# 10. Llogarit metrikat
mae = mean_absolute_error(y_test, y_pred)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
r2 = r2_score(y_test, y_pred)

# 11. Printo rezultatet
print("\n========== Random Forest Regressor Results ==========")
print(f"Best Parameters: {grid_search_rf.best_params_}")
print(f"Mean Absolute Error (MAE): {mae:.4f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.4f}")
print(f"R² Score: {r2:.4f}")
print("======================================================")
# Out:
# ========== Random Forest Regressor Results ==========
# Best Parameters: {'max_depth': None, 'min_samples_split': 2, 'n_estimators': 10}
# Mean Absolute Error (MAE): 0.9511
# Root Mean Squared Error (RMSE): 1.2823
# R² Score: 0.0950
# ...

# %%
# 1. Importimi i librarive
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import pandas as pd
import numpy as np


# 3. Përzgjedhja e input features dhe target
feature_cols = [
    'runtimeMinutes', 
    'ratingCount', 
    'awardWins', 
    'companiesNumber', 
    'writerCredits', 
    'directorsCredits', 
    'totalImages', 
    'totalVideos', 
    'quotesTotal', 
    'durationYears'
]

X = df[feature_cols]
y = df['averageRating']

# 4. Ndajmë në train/test sets (70% train, 30% test)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# 5. Definimi i Random Forest dhe parametrat për GridSearch
param_grid = {
    'n_estimators': [100],  # Zvogëlojmë pak për laptop të lehtë
    'max_depth': [None, 10, 20],
    'min_samples_split': [5]
}

rf = RandomForestRegressor(random_state=42)

# 6. GridSearchCV (me n_jobs=1 për më shumë stabilitet në MacBook Air)
grid_search_rf = GridSearchCV(
    estimator=rf,
    param_grid=param_grid,
    cv=5,
    scoring='neg_mean_absolute_error',
    n_jobs=1  # Një CPU core, për të mos e ngarkuar shumë
)

# 7. Trajno modelin
grid_search_rf.fit(X_train, y_train)

# 8. Modeli më i mirë
best_rf = grid_search_rf.best_estimator_

# 9. Predikto mbi test set
y_pred = best_rf.predict(X_test)

# 10. Llogarit metrikat
mae = mean_absolute_error(y_test, y_pred)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
r2 = r2_score(y_test, y_pred)

# 11. Printo rezultatet
print("\n========== Random Forest Regressor Results ==========")
print(f"Best Parameters: {grid_search_rf.best_params_}")
print(f"Mean Absolute Error (MAE): {mae:.4f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.4f}")
print(f"R² Score: {r2:.4f}")
print("======================================================")
# Out:
# ========== Random Forest Regressor Results ==========
# Best Parameters: {'max_depth': 20, 'min_samples_split': 5, 'n_estimators': 100}
# Mean Absolute Error (MAE): 0.8874
# Root Mean Squared Error (RMSE): 1.1960
# R² Score: 0.2127
# ...

# %% [markdown]
# #### ridge

# %%
# 1. Importimi i librarive për Ridge
from sklearn.linear_model import Ridge
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

# 2. Definimi i input features dhe target (nëse nuk janë lart përcaktuar)
# X = df[feature_cols]
# y = df['averageRating']

# 3. Ndajmë në train/test sets (nëse nuk e kemi ndarë ende)
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# 4. Definimi i modelit Ridge dhe parametrat për GridSearch
ridge_param_grid = {
    'alpha': [0.01, 0.1, 1, 10, 100]  # kontrollojmë penalizimin
}

ridge = Ridge(random_state=42)

# 5. GridSearchCV për Ridge
grid_search_ridge = GridSearchCV(
    estimator=ridge,
    param_grid=ridge_param_grid,
    scoring='neg_mean_absolute_error',
    cv=5,
    n_jobs=1  # Përsëri 1 core që të mos lodhim shumë MacBook Air
)

# 6. Trajno modelin
grid_search_ridge.fit(X_train, y_train)

# 7. Modeli më i mirë
best_ridge = grid_search_ridge.best_estimator_

# 8. Predikto mbi test set
y_pred_ridge = best_ridge.predict(X_test)

# 9. Llogarit metrikat
mae_ridge = mean_absolute_error(y_test, y_pred_ridge)
rmse_ridge = np.sqrt(mean_squared_error(y_test, y_pred_ridge))
r2_ridge = r2_score(y_test, y_pred_ridge)

# 10. Printo rezultatet
print("\n========== Ridge Regression Results ==========")
print(f"Best Alpha: {grid_search_ridge.best_params_}")
print(f"Ridge MAE: {mae_ridge:.4f}")
print(f"Ridge RMSE: {rmse_ridge:.4f}")
print(f"Ridge R² Score: {r2_ridge:.4f}")
print("===============================================")
# Out:
# ========== Ridge Regression Results ==========
# Best Alpha: {'alpha': 0.01}
# Ridge MAE: 1.0130
# Ridge RMSE: 1.3290
# Ridge R² Score: 0.0279
# ...

# %% [markdown]
# ### gradient boosting regressor

# %%
# 1. Importimi i librarive
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

# 2. Përdorim të njëjtin Train/Test split
# (X_train, X_test, y_train, y_test janë krijuar më parë)

# 3. Definimi i Gradient Boosting dhe parametrave për GridSearch
param_grid_gb = {
    'n_estimators': [100, 300],  # Sa shumë modele të vegjël
    'learning_rate': [0.05, 0.1],  # Sa shpejt mëson (më e ulët = më e saktë por më e ngadaltë)
    'max_depth': [3, 5]  # Thellësia e pemëve
}

gb = GradientBoostingRegressor(random_state=42)

# 4. GridSearchCV për Gradient Boosting
grid_search_gb = GridSearchCV(
    estimator=gb,
    param_grid=param_grid_gb,
    scoring='neg_mean_absolute_error',
    cv=5,
    n_jobs=1  # Përdorim vetëm një core për stabilitet
)

# 5. Trajno modelin
grid_search_gb.fit(X_train, y_train)

# 6. Modeli më i mirë
best_gb = grid_search_gb.best_estimator_

# 7. Predikto mbi test set
y_pred_gb = best_gb.predict(X_test)

# 8. Llogarit metrikat
mae_gb = mean_absolute_error(y_test, y_pred_gb)
rmse_gb = np.sqrt(mean_squared_error(y_test, y_pred_gb))
r2_gb = r2_score(y_test, y_pred_gb)

# 9. Printo rezultatet
print("\n========== Gradient Boosting Regressor Results ==========")
print(f"Best Parameters: {grid_search_gb.best_params_}")
print(f"GB MAE: {mae_gb:.4f}")
print(f"GB RMSE: {rmse_gb:.4f}")
print(f"GB R² Score: {r2_gb:.4f}")
print("=========================================================")
# Out:
# ========== Gradient Boosting Regressor Results ==========
# Best Parameters: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 300}
# GB MAE: 0.8967
# GB RMSE: 1.2004
# GB R² Score: 0.2070
# ...
